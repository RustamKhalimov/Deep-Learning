# %% [markdown]
# Step 1 import liblaries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os

# %% [markdown]
# Step 2 Set constants

# %%
img_height = 150
img_width = 150
baTch_size = 32
EPOCHS = 15
train_dir = 'dataset/train'
validation_dir = 'dataset/validation'

# %% [markdown]
# Part 3 Prepare data generators

# %%
train_datagen = keras.preprocessing.image.ImageDataGenerator(
    rescale = 1.0 / 255,
    rotation_range = 20 , 
    width_shift_range = 0.1 ,
    height_shift_range = 0.1 ,
    shear_range = 0.1 , 
    zoom_range = 0.1 , 
    horizontal_flip = True ,
    fill_mode = 'nearest'
)

# %%
val_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1.0 / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir , 
    target_size = (img_height , img_width) , 
    batch_size = baTch_size , 
    class_mode = 'binary'
)
# Out:
# Found 1999 images belonging to 3 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    validation_dir,
    target_size = (img_height , img_width),
    batch_size = baTch_size,
    class_mode = 'binary'
)
# Out:
# Found 800 images belonging to 3 classes.

# %% [markdown]
# Step 4. Build the baseline model

# %%
def build_baseline_model():
    model = keras.Sequential([
        #Block 1
        layers.Conv2D(32 , (3,3) , activation = 'relu' , input_shape = (img_height , img_width , 3)),
        layers.MaxPool2D(2,2),

        #Block 2
        layers.Conv2D(64 , (3,3) , activation = 'relu' ),
        layers.MaxPool2D(2,2),

        #Block 3
        layers.Conv2D(32 , (3,3) , activation = 'relu' ),
        layers.MaxPool2D(2,2),

        #Classifier
        layers.Flatten(),
        layers.Dense(128 , activation = 'relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation = 'sigmoid')
        
    ])
    return model

model = build_baseline_model()
model.summary()
# Out:
# C:\Users\RHali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 34, 34, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 17, 17, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9248)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,183,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,221,857 (4.66 MB)
#  Trainable params: 1,221,857 (4.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Additional step: Cleaning my DB

# %%
import os
from PIL import Image

def remove_corrupted_images(folder):

    for root, dirs, files in os.walk(folder):
        for file in files:
            path = os.path.join(root, file)

            try:
                img = Image.open(path)
                img.verify()
            except:
                print("Removing:", path)
                os.remove(path)

remove_corrupted_images(train_dir)
remove_corrupted_images(validation_dir)

# %% [markdown]
# Step 5. Compile and train

# %%
model.compile(
    optimizer = 'adam' ,
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)
history = model.fit(
    train_generator,
    epochs = EPOCHS,
    validation_data = val_generator
)
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 59s 873ms/step - accuracy: 0.4962 - loss: -494342.9062 - val_accuracy: 0.5000 - val_loss: -3567555.7500
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 854ms/step - accuracy: 0.4997 - loss: -79055896.0000 - val_accuracy: 0.5000 - val_loss: -314634880.0000
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 849ms/step - accuracy: 0.4997 - loss: -1579482624.0000 - val_accuracy: 0.5000 - val_loss: -4233686016.0000
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 866ms/step - accuracy: 0.4997 - loss: -11832962048.0000 - val_accuracy: 0.5000 - val_loss: -25113669632.0000
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 844ms/step - accuracy: 0.4997 - loss: -53129650176.0000 - val_accuracy: 0.5000 - val_loss: -95625854976.0000
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 834ms/step - accuracy: 0.4997 - loss: -167891943424.0000 - val_accuracy: 0.5000 - val_loss: -275884376064.0000
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 870ms/step - accuracy: 0.4997 - loss: -436532412416.0000 - val_accuracy: 0.5000 - val_loss: -658938855424.0000
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 887ms/step - accuracy: 0.4997 - loss: -973799620608.0000 - val_accuracy: 0.5000 - val_loss: -1379534897152.0000
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 896ms/step - accuracy: 0.4997 - loss: -1915232845824.0000 - val_accuracy: 0.5000 - val_loss: -2618661797888.0000
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 867ms/step - accuracy: 0.4997 - loss: -3472863526912.0000 - val_accuracy: 0.5000 - val_loss: -4551334166528.0000
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 888ms/step - accuracy: 0.4997 - loss: -5854961598464.0000 - val_accuracy: 0.5000 - val_loss: -7516790456320.0000
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 80s 863ms/step - accuracy: 0.4997 - loss: -9313333542912.0000 - val_accuracy: 0.5000 - val_loss: -11769834635264.0000
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 863ms/step - accuracy: 0.4997 - loss: -14426603257856.0000 - val_accuracy: 0.5000 - val_loss: -17716752678912.0000
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 867ms/step - accuracy: 0.4997 - loss: -21268950679552.0000 - val_accuracy: 0.5000 - val_loss: -25747712376832.0000
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 860ms/step - accuracy: 0.4997 - loss: -30504160067584.0000 - val_accuracy: 0.5000 - val_loss: -36231580745728.0000

# %% [markdown]
# Step 6. Plot training curves

# %%
def plot_history(history , title = ''):
    fig , axes = plt.subplots(1 , 2 , figsize = (12 , 4))

    axes[0].plot(history.history['accuracy'], label='train acc')
    axes[0].plot(history.history['val_accuracy'], label='val acc')
    axes[0].set_title(f'Accuracy {title}')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    
    axes[1].plot(history.history['loss'], label='train loss')
    axes[1].plot(history.history['val_loss'], label='val loss')
    axes[1].set_title(f'Loss {title}')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    
    plt.tight_layout()
    plt.show()


plot_history(history, title='(Baseline)')

# %% [markdown]
# Experiment A: Fewer filters (simpler model)

# %%
def build_model_A():

    model = keras.Sequential([

        
        #Block 1
        layers.Conv2D(8, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
        layers.MaxPooling2D(2, 2),
        
        #Block 2
        layers.Conv2D(16, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),
        
        #Block 3
        layers.Conv2D(32, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),
        
        #Classifier
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    return model


model_A = build_model_A()
model_A.compile(optimizer='adam', loss='binary_crossentropy',

metrics=['accuracy'])
history_A = model_A.fit(train_generator, epochs=EPOCHS,

validation_data=val_generator)
plot_history(history_A, title='(Experiment A — fewer filters)')
# Out:
# C:\Users\RHali\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 53s 767ms/step - accuracy: 0.4962 - loss: -31766.4473 - val_accuracy: 0.5000 - val_loss: -247039.8438
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 741ms/step - accuracy: 0.4997 - loss: -5925263.0000 - val_accuracy: 0.5000 - val_loss: -23230064.0000
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 47s 747ms/step - accuracy: 0.4997 - loss: -118542536.0000 - val_accuracy: 0.5000 - val_loss: -317567680.0000
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 731ms/step - accuracy: 0.4997 - loss: -923179456.0000 - val_accuracy: 0.5000 - val_loss: -1914771584.0000
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 740ms/step - accuracy: 0.4997 - loss: -4013886976.0000 - val_accuracy: 0.5000 - val_loss: -7288351744.0000
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 732ms/step - accuracy: 0.4997 - loss: -12778471424.0000 - val_accuracy: 0.5000 - val_loss: -20928086016.0000
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 47s 747ms/step - accuracy: 0.4997 - loss: -33174102016.0000 - val_accuracy: 0.5000 - val_loss: -49556209664.0000
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 733ms/step - accuracy: 0.4997 - loss: -72801247232.0000 - val_accuracy: 0.5000 - val_loss: -103914528768.0000
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 753ms/step - accuracy: 0.4997 - loss: -142521466880.0000 - val_accuracy: 0.5000 - val_loss: -196026515456.0000
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 732ms/step - accuracy: 0.4997 - loss: -258300477440.0000 - val_accuracy: 0.5000 - val_loss: -343612096512.0000
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 732ms/step - accuracy: 0.4997 - loss: -439796858880.0000 - val_accuracy: 0.5000 - val_loss: -566115762176.0000
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 733ms/step - accuracy: 0.4997 - loss: -715739889664.0000 - val_accuracy: 0.5000 - val_loss: -889051676672.0000
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 384ms/step - accuracy: 0.4997 - loss: -1089130201088.0000 - val_accuracy: 0.5000 - val_loss: -1340269395968.0000
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 304ms/step - accuracy: 0.4997 - loss: -1602367127552.0000 - val_accuracy: 0.5000 - val_loss: -1942560309248.0000
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 320ms/step - accuracy: 0.4997 - loss: -2282787700736.0000 - val_accuracy: 0.5000 - val_loss: -2727442120704.0000

# %% [markdown]
# Experiment B: No pooling layers

# %%
def build_model_B():

    model = keras.Sequential([

        layers.Conv2D(32, (3, 3), strides=2, activation='relu', input_shape = (img_height , img_width , 3)),
        layers.Conv2D(64, (3, 3), strides=2, activation='relu'),
        layers.Conv2D(128, (3, 3), strides=2, activation='relu'),

        # Classifier
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')

    ])

    return model

model_B = build_model_B()

model_B.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_B = model_B.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

plot_history(history_B, title='(Experiment B — No Pooling)')
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.4972 - loss: -1169816.3750 - val_accuracy: 0.5000 - val_loss: -8740508.0000
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 344ms/step - accuracy: 0.4997 - loss: -194010800.0000 - val_accuracy: 0.5000 - val_loss: -791314944.0000
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 344ms/step - accuracy: 0.4997 - loss: -3985783552.0000 - val_accuracy: 0.5000 - val_loss: -10841651200.0000
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 0.4997 - loss: -30816837632.0000 - val_accuracy: 0.5000 - val_loss: -66238808064.0000
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 345ms/step - accuracy: 0.4997 - loss: -138869981184.0000 - val_accuracy: 0.5000 - val_loss: -251912536064.0000
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 337ms/step - accuracy: 0.4997 - loss: -442424295424.0000 - val_accuracy: 0.5000 - val_loss: -723937525760.0000
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 336ms/step - accuracy: 0.4997 - loss: -1152931856384.0000 - val_accuracy: 0.5000 - val_loss: -1741679755264.0000
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 327ms/step - accuracy: 0.4997 - loss: -2545867554816.0000 - val_accuracy: 0.5000 - val_loss: -3616699056128.0000
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 0.4997 - loss: -5017451364352.0000 - val_accuracy: 0.5000 - val_loss: -6855997259776.0000
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 323ms/step - accuracy: 0.4997 - loss: -9018418397184.0000 - val_accuracy: 0.5000 - val_loss: -12026714783744.0000
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 0.4997 - loss: -15299240787968.0000 - val_accuracy: 0.5000 - val_loss: -19655397736448.0000
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.4997 - loss: -24635164852224.0000 - val_accuracy: 0.5000 - val_loss: -30835744964608.0000
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.4997 - loss: -37229321781248.0000 - val_accuracy: 0.5000 - val_loss: -46068687437824.0000
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 335ms/step - accuracy: 0.4997 - loss: -55236714561536.0000 - val_accuracy: 0.5000 - val_loss: -67390037557248.0000
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.4997 - loss: -78573146734592.0000 - val_accuracy: 0.5000 - val_loss: -93618157125632.0000

# %% [markdown]
# Experiment C: No dropout (overfitting test)

# %%
def build_model_C():

    model = keras.Sequential([

        # Block 1
        layers.Conv2D(32, (3, 3), activation='relu' ,  input_shape = (img_height , img_width , 3)),
        layers.MaxPooling2D(2, 2),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),

        # Classifier
        layers.Flatten(),
        layers.Dense(128, activation='relu'),

        # Dropout removed (overfitting test)
        layers.Dense(1, activation='sigmoid')

    ])

    return model

model_C = build_model_C()

model_C.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_C = model_C.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

plot_history(history_C, title='(Experiment C — No Dropout)')
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 450ms/step - accuracy: 0.4902 - loss: -2310184.7500 - val_accuracy: 0.5000 - val_loss: -17201096.0000
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 579ms/step - accuracy: 0.4997 - loss: -381743456.0000 - val_accuracy: 0.5000 - val_loss: -1567088512.0000
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 548ms/step - accuracy: 0.4997 - loss: -8122684928.0000 - val_accuracy: 0.5000 - val_loss: -21372524544.0000
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 476ms/step - accuracy: 0.4997 - loss: -60724420608.0000 - val_accuracy: 0.5000 - val_loss: -128138469376.0000
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 478ms/step - accuracy: 0.4997 - loss: -271681961984.0000 - val_accuracy: 0.5000 - val_loss: -482615164928.0000
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 508ms/step - accuracy: 0.4997 - loss: -866420326400.0000 - val_accuracy: 0.5000 - val_loss: -1395100745728.0000
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 509ms/step - accuracy: 0.4997 - loss: -2203385856000.0000 - val_accuracy: 0.5000 - val_loss: -3317191147520.0000
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 494ms/step - accuracy: 0.4997 - loss: -4886561292288.0000 - val_accuracy: 0.5000 - val_loss: -6943166955520.0000
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 471ms/step - accuracy: 0.4997 - loss: -9611268587520.0000 - val_accuracy: 0.5000 - val_loss: -13111864066048.0000
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 519ms/step - accuracy: 0.4997 - loss: -17372014444544.0000 - val_accuracy: 0.5000 - val_loss: -22903716315136.0000
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 507ms/step - accuracy: 0.4997 - loss: -29307632091136.0000 - val_accuracy: 0.5000 - val_loss: -37626681753600.0000
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 686ms/step - accuracy: 0.4997 - loss: -46793748381696.0000 - val_accuracy: 0.5000 - val_loss: -58391753916416.0000
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 581ms/step - accuracy: 0.4997 - loss: -71528460845056.0000 - val_accuracy: 0.5000 - val_loss: -88142593916928.0000
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 611ms/step - accuracy: 0.4997 - loss: -105147099250688.0000 - val_accuracy: 0.5000 - val_loss: -127429876121600.0000
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 626ms/step - accuracy: 0.4997 - loss: -150249431629824.0000 - val_accuracy: 0.5000 - val_loss: -179533139410944.0000

# %% [markdown]
# Experiment D: Different optimizer and learning rate

# %%
def build_model_D():
    return build_baseline_model()



model_D = build_model_D()


model_D.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_D = model_D.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

plot_history(history_D, title='(Experiment D — SGD lr=0.01)')
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 406ms/step - accuracy: 0.0875 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 395ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 491ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 502ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 446ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 451ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 422ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 424ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 441ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 427ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 428ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 27s 426ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 445ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 517ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 483ms/step - accuracy: 0.0000e+00 - loss: nan - val_accuracy: 0.0000e+00 - val_loss: nan

# %% [markdown]
# Experiment E: Deeper network (add a 4th conv block)

# %%
def build_model_E():

    model = keras.Sequential([

        # Block 1
        layers.Conv2D(32, (3, 3), activation='relu' , input_shape = (img_height , img_width , 3)),
        layers.MaxPooling2D(2, 2),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),

        # NEW Block 
        layers.Conv2D(256, (3, 3), activation='relu'),
        layers.MaxPooling2D(2, 2),

        # Classifier
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')

    ])

    return model

model_E = build_model_E()

model_E.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_E = model_E.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

plot_history(history_E, title='(Experiment E — Deeper Network)')
# Out:
# Epoch 1/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 478ms/step - accuracy: 0.4977 - loss: -51965592.0000 - val_accuracy: 0.5000 - val_loss: -473001664.0000
# Epoch 2/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 602ms/step - accuracy: 0.4997 - loss: -29049077760.0000 - val_accuracy: 0.5000 - val_loss: -141818183680.0000
# Epoch 3/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 653ms/step - accuracy: 0.4997 - loss: -1176951455744.0000 - val_accuracy: 0.5000 - val_loss: -3756913328128.0000
# Epoch 4/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 604ms/step - accuracy: 0.4997 - loss: -14651882471424.0000 - val_accuracy: 0.5000 - val_loss: -35411292323840.0000
# Epoch 5/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 596ms/step - accuracy: 0.4997 - loss: -91385604603904.0000 - val_accuracy: 0.5000 - val_loss: -187275707154432.0000
# Epoch 6/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 620ms/step - accuracy: 0.4997 - loss: -393772835799040.0000 - val_accuracy: 0.5000 - val_loss: -701935900426240.0000
# Epoch 7/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 588ms/step - accuracy: 0.4997 - loss: -1261845688090624.0000 - val_accuracy: 0.5000 - val_loss: -2062297132433408.0000
# Epoch 8/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 585ms/step - accuracy: 0.4997 - loss: -3327667378061312.0000 - val_accuracy: 0.5000 - val_loss: -5101448337555456.0000
# Epoch 9/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 581ms/step - accuracy: 0.4997 - loss: -7723742230740992.0000 - val_accuracy: 0.5000 - val_loss: -11332459115315200.0000
# Epoch 10/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 576ms/step - accuracy: 0.4997 - loss: -15960689029939200.0000 - val_accuracy: 0.5000 - val_loss: -22397747642499072.0000
# Epoch 11/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 565ms/step - accuracy: 0.4997 - loss: -30553239850057728.0000 - val_accuracy: 0.5000 - val_loss: -41095342304788480.0000
# Epoch 12/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 572ms/step - accuracy: 0.4997 - loss: -53938054729039872.0000 - val_accuracy: 0.5000 - val_loss: -71351978155835392.0000
# Epoch 13/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 581ms/step - accuracy: 0.4997 - loss: -91227553498398720.0000 - val_accuracy: 0.5000 - val_loss: -117116576976601088.0000
# Epoch 14/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 575ms/step - accuracy: 0.4997 - loss: -146602558255792128.0000 - val_accuracy: 0.5000 - val_loss: -183916461029326848.0000
# Epoch 15/15
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 565ms/step - accuracy: 0.4997 - loss: -224944582800965632.0000 - val_accuracy: 0.5000 - val_loss: -280171608755142656.0000
